# %%
import gym_super_mario_bros
from gym_super_mario_bros.actions import RIGHT_ONLY
from nes_py.wrappers import JoypadSpace
from pl_bolts.models.rl.common.gym_wrappers import MaxAndSkipEnv
from gym.wrappers import GrayScaleObservation, ResizeObservation, FrameStack, TransformObservation, RecordVideo
from icecream import ic

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, RIGHT_ONLY)
# env = RecordVideo(env, "test_video", lambda x: x % 1 == 0)
# env = MaxAndSkipEnv(env, skip=4)
# env = GrayScaleObservation(env, keep_dim=False)
# env = ResizeObservation(env, shape=84)
# env = TransformObservation(env, f = lambda x: x / 255.)
# env = FrameStack(env, num_stack=4)
env.reset()

# %%
import matplotlib.pyplot as plt
done = False
while True:
    if done:
        env.reset()
    obs, reward, done, info = env.step(env.action_space.sample())
    ic(obs.shape)
    env.render()
# Out:
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ic| obs.shape: (4, 84, 84, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4599/1841823717.py in <module>
#       5         env.reset()
#       6     obs, reward, done, info = env.step(env.action_space.sample())
# ----> 7     ic(obs.shape)
#       8     env.render()
#
# ~/anaconda3/envs/qmario/lib/python3.7/site-packages/icecream/icecream.py in __call__(self, *args)
#     204             callFrame = inspect.currentframe().f_back
#     205             try:
# --> 206                 out = self._format(callFrame, *args)
#     207             except NoSourceAvailableError as err:
#     208                 prefix = callOrValue(self.prefix)
#
# ~/anaconda3/envs/qmario/lib/python3.7/site-packages/icecream/icecream.py in _format(self, callFrame, *args)
#     231             raise NoSourceAvailableError()
#     232
# --> 233         context = self._formatContext(callFrame, callNode)
#     234         if not args:
#     235             time = self._formatTime()
#
# ~/anaconda3/envs/qmario/lib/python3.7/site-packages/icecream/icecream.py in _formatContext(self, callFrame, callNode)
#     314     def _formatContext(self, callFrame, callNode):
#     315         filename, lineNumber, parentFunction = self._getContext(
# --> 316             callFrame, callNode)
#     317
#     318         if parentFunction != '<module>':
#
# ~/anaconda3/envs/qmario/lib/python3.7/site-packages/icecream/icecream.py in _getContext(self, callFrame, callNode)
#     329     def _getContext(self, callFrame, callNode):
#     330         lineNumber = callNode.lineno
# --> 331         frameInfo = inspect.getframeinfo(callFrame)
#     332         parentFunction = frameInfo.function
#     333         filename = basename(frameInfo.filename)
#
# ~/anaconda3/envs/qmario/lib/python3.7/inspect.py in getframeinfo(frame, context)
#    1462         start = lineno - 1 - context//2
#    1463         try:
# -> 1464             lines, lnum = findsource(frame)
#    1465         except OSError:
#    1466             lines = index = None
#
# ~/anaconda3/envs/qmario/lib/python3.7/inspect.py in findsource(object)
#     778             raise OSError('source code not available')
#     779
# --> 780     module = getmodule(object, file)
#     781     if module:
#     782         lines = linecache.getlines(file, module.__dict__)
#
# ~/anaconda3/envs/qmario/lib/python3.7/inspect.py in getmodule(object, _filename)
#     731     # Copy sys.modules in order to cope with changes while iterating
#     732     for modname, module in sys.modules.copy().items():
# --> 733         if ismodule(module) and hasattr(module, '__file__'):
#     734             f = module.__file__
#     735             if f == _filesbymodname.get(modname, None):
#
# KeyboardInterrupt:
